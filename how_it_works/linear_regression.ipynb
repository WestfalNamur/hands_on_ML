# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# When implementing linear regression of some dependent variable 𝑦 on the set of independent variables 𝐱 = (𝑥₁, …, 𝑥ᵣ), where 𝑟 is the number of predictors, you assume a linear relationship between 𝑦 and 𝐱: 𝑦 = 𝛽₀ + 𝛽₁𝑥₁ + ⋯ + 𝛽ᵣ𝑥ᵣ + 𝜀. This equation is the regression equation. 𝛽₀, 𝛽₁, …, 𝛽ᵣ are the regression coefficients, and 𝜀 is the random error.

# %% [markdown]
# Linear regression calculates the estimators of the regression coefficients or simply the predicted weights, denoted with 𝑏₀, 𝑏₁, …, 𝑏ᵣ. They define the estimated regression function 𝑓(𝐱) = 𝑏₀ + 𝑏₁𝑥₁ + ⋯ + 𝑏ᵣ𝑥ᵣ. This function should capture the dependencies between the inputs and output sufficiently well.

# %% [markdown]
# The estimated or predicted response, 𝑓(𝐱ᵢ), for each observation 𝑖 = 1, …, 𝑛, should be as close as possible to the corresponding actual response 𝑦ᵢ. The differences 𝑦ᵢ - 𝑓(𝐱ᵢ) for all observations 𝑖 = 1, …, 𝑛, are called the residuals. Regression is about determining the best predicted weights, that is the weights corresponding to the smallest residuals.

# %% [markdown]
# To get the best weights, you usually minimize the sum of squared residuals (SSR) for all observations 𝑖 = 1, …, 𝑛: SSR = Σᵢ(𝑦ᵢ - 𝑓(𝐱ᵢ))². This approach is called the method of ordinary least squares.

# %% [markdown]
# Multiple or multivariate linear regression is a case of linear regression with two or more independent variables.

# %% [markdown]
# Polynomial regression as a generalized case of linear regression. You assume the polynomial dependence between the output and inputs and, consequently, the polynomial estimated regression function

# %%
# Generater random data
m = 1000
X = np.random.randn(m, 1)
y = 2*X + 1 + 1.2*np.random.randn(m, 1)

# %%
# Normalize
X = X/(np.max(X))
y = y/(np.max(y))

# %%
# Plot
plt.plot(X, y, "r.") 
plt.show()

# %%
th = np.linalg.inv(X.T.dot(X)).dot(X.T).dot(y)
print(beta_hat)
# Out:
# [[0.75386464]]

# %%
# predict using coefficients
y_i = X.dot(beta_hat)

# %%
plt.scatter(X, y)
plt.plot(X, y_i, color='red')

# %%
def estimate_theta(X, y):  
    return np.linalg.inv(X.T .dot(X)).dot(X.T).dot(y)

# %%
X_b = np.c_[np.ones((m, 1)), X] # set bias term to 1 for each sample  
params = estimate_theta(X_b, y)  
print(params)

# %%
test_X = np.array([-1, 1])  
test_X_b = np.c_[np.ones((2, 1)), test_X]  
  
prediction = test_X_b.dot(params)

# %%
plt.plot(test_X, prediction, "r--")  
plt.plot(X, y, "b.")  
plt.axis([-1, 1, -1, 1]) # x axis range 0 to 2, y axis range 0 to 15  
plt.show()
